# %%
import pandas as pd
w=pd.read_csv("C:/Users/hp/Downloads/Github/dataset1-master/winedataset.csv")
df=pd.DataFrame(w)

# %%
df.head()
# Out:
#    Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  diluted wines  Proline
# 0             5.64  1.04           3.92     1065
# 1             4.38  1.05           3.40     1050
# 2             5.68  1.03           3.17     1185
# 3             7.80  0.86           3.45     1480
# 4             4.32  1.04           2.93      735

# %%
df.isnull().sum()
# Out:
# Class                   0
# Alcohol                 0
# Malic acid              0
# Ash                     0
# Alcalinity of ash       0
# Magnesium               0
# Total phenols           0
# Flavanoids              0
# Nonflavanoid phenols    0
# Proanthocyanins         0
# Color intensity         0
# Hue                     0
# diluted wines           0
# Proline                 0
# dtype: int64

# %%
df.shape
# Out:
# (178, 14)

# %%
df.plot(kind='box',subplots=True,layout=(4,4))
# Out:
# Class                      AxesSubplot(0.125,0.712609;0.168478x0.167391)
# Alcohol                 AxesSubplot(0.327174,0.712609;0.168478x0.167391)
# Malic acid              AxesSubplot(0.529348,0.712609;0.168478x0.167391)
# Ash                     AxesSubplot(0.731522,0.712609;0.168478x0.167391)
# Alcalinity of ash          AxesSubplot(0.125,0.511739;0.168478x0.167391)
# Magnesium               AxesSubplot(0.327174,0.511739;0.168478x0.167391)
# Total phenols           AxesSubplot(0.529348,0.511739;0.168478x0.167391)
# Flavanoids              AxesSubplot(0.731522,0.511739;0.168478x0.167391)
# Nonflavanoid phenols        AxesSubplot(0.125,0.31087;0.168478x0.167391)
# Proanthocyanins          AxesSubplot(0.327174,0.31087;0.168478x0.167391)
# Color intensity          AxesSubplot(0.529348,0.31087;0.168478x0.167391)
# Hue                      AxesSubplot(0.731522,0.31087;0.168478x0.167391)
# diluted wines                  AxesSubplot(0.125,0.11;0.168478x0.167391)
# Proline                     AxesSubplot(0.327174,0.11;0.168478x0.167391)
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.describe()
# Out:
#             Class     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# min     70.000000       0.980000    0.340000              0.130000
# 25%     88.000000       1.742500    1.205000              0.270000
# 50%     98.000000       2.355000    2.135000              0.340000
# 75%    107.000000       2.800000    2.875000              0.437500
# max    162.000000       3.880000    5.080000              0.660000
#
#        Proanthocyanins  Color intensity         Hue  diluted wines  \
# count       178.000000       178.000000  178.000000     178.000000
# mean          1.590899         5.058090    0.957449       2.611685
# std           0.572359         2.318286    0.228572       0.709990
# min           0.410000         1.280000    0.480000       1.270000
# 25%           1.250000         3.220000    0.782500       1.937500
# 50%           1.555000         4.690000    0.965000       2.780000
# 75%           1.950000         6.200000    1.120000       3.170000
# max           3.580000        13.000000    1.710000       4.000000
#
#            Proline
# count   178.000000
# mean    746.893258
# std     314.907474
# min     278.000000
# 25%     500.500000
# 50%     673.500000
# 75%     985.000000
# max    1680.000000

# %%
df['Color intensity'].plot.box()

# %%
import numpy as np
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[1.21394365, 1.51861254, 0.5622498 , ..., 0.36217728, 1.84791957,
#         1.01300893],
#        [1.21394365, 0.24628963, 0.49941338, ..., 0.40605066, 1.1134493 ,
#         0.96524152],
#        [1.21394365, 0.19687903, 0.02123125, ..., 0.31830389, 0.78858745,
#         1.39514818],
#        ...,
#        [1.37386437, 0.33275817, 1.74474449, ..., 1.61212515, 1.48544548,
#         0.28057537],
#        [1.37386437, 0.20923168, 0.22769377, ..., 1.56825176, 1.40069891,
#         0.29649784],
#        [1.37386437, 1.39508604, 1.58316512, ..., 1.52437837, 1.42894777,
#         0.59516041]])

# %%
print(np.where(z>3))
# Out:
# (array([ 25,  59,  69,  73,  95, 110, 115, 121, 121, 123, 158], dtype=int64), array([ 3,  3,  5,  4,  5,  9, 11,  3,  7,  2, 10], dtype=int64))

# %%
z[25,3]
# Out:
# 3.1197718608780005

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new.describe()
# Out:
#             Class     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  168.000000  168.000000  168.000000  168.000000         168.000000
# mean     1.934524   13.033214    2.343571    2.369226          19.361310
# std      0.790209    0.793084    1.097823    0.243202           3.118708
# min      1.000000   11.410000    0.740000    1.700000          11.200000
# 25%      1.000000   12.370000    1.610000    2.230000          17.175000
# 50%      2.000000   13.060000    1.870000    2.360000          19.250000
# 75%      3.000000   13.695000    3.105000    2.542500          21.500000
# max      3.000000   14.830000    5.650000    2.920000          28.500000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  168.000000     168.000000  168.000000            168.000000
# mean    98.779762       2.273988    2.010298              0.362679
# std     12.560477       0.627890    0.985189              0.123940
# min     70.000000       0.980000    0.340000              0.130000
# 25%     88.000000       1.700000    1.097500              0.270000
# 50%     97.500000       2.265000    2.100000              0.340000
# 75%    106.250000       2.800000    2.885000              0.430000
# max    136.000000       3.880000    3.930000              0.660000
#
#        Proanthocyanins  Color intensity         Hue  diluted wines  \
# count       168.000000       168.000000  168.000000     168.000000
# mean          1.553155         5.116726    0.951226       2.596607
# std           0.529569         2.243267    0.220522       0.714607
# min           0.410000         1.280000    0.480000       1.270000
# 25%           1.235000         3.292500    0.787500       1.905000
# 50%           1.505000         4.850000    0.960000       2.775000
# 75%           1.870000         6.262500    1.112500       3.170000
# max           2.960000        11.750000    1.450000       4.000000
#
#            Proline
# count   168.000000
# mean    752.875000
# std     319.272211
# min     278.000000
# 25%     501.500000
# 50%     675.000000
# 75%    1016.250000
# max    1680.000000

# %%
from scipy.stats import boxcox

# %%
df['Magnesium']=boxcox(df['Magnesium'],0)

# %%
df['Proline']=boxcox(df['Proline'],0)

# %%
df.drop(['Color intensity'],axis=1,inplace=True)

# %%
df.describe()
# Out:
#             Class     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean     4.593042       2.295112    2.029270              0.361854
# std      0.136627       0.625851    0.998859              0.124453
# min      4.248495       0.980000    0.340000              0.130000
# 25%      4.477337       1.742500    1.205000              0.270000
# 50%      4.584967       2.355000    2.135000              0.340000
# 75%      4.672829       2.800000    2.875000              0.437500
# max      5.087596       3.880000    5.080000              0.660000
#
#        Proanthocyanins         Hue  diluted wines     Proline
# count       178.000000  178.000000     178.000000  178.000000
# mean          1.590899    0.957449       2.611685    6.530303
# std           0.572359    0.228572       0.709990    0.415107
# min           0.410000    0.480000       1.270000    5.627621
# 25%           1.250000    0.782500       1.937500    6.215606
# 50%           1.555000    0.965000       2.780000    6.512486
# 75%           1.950000    1.120000       3.170000    6.892642
# max           3.580000    1.710000       4.000000    7.426549

# %%
sns.pairplot(df)

# %%
x=df.iloc[:,1:]
y=df.iloc[:,0]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
import warnings
warnings.filterwarnings('ignore')
r_score=0
for r_state in range(42,101):
    x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = r_state,test_size=0.33)
    lr=LogisticRegression()
    lr.fit(x_train,y_train)
    y_pred = lr.predict(x_test)
    accuracy=accuracy_score(y_test,y_pred)
    if accuracy>r_score:
        r_score=accuracy
        final_r_state=r_state

print("max r2 score corresponding to ",final_r_state," is ",r_score)
# Out:
# max r2 score corresponding to  48  is  1.0

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = 48,test_size=0.20)
lr=LogisticRegression()
lr.fit(x_train,y_train)
lr.score(x_train,y_train)
# Out:
# 0.9507042253521126

# %%
predlr=lr.predict(x_test)
print(accuracy_score(y_test,predlr))
print(confusion_matrix(y_test,predlr))
print(classification_report(y_test,predlr))
# Out:
# 1.0
# [[ 7  0  0]
#  [ 0 15  0]
#  [ 0  0 14]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         7
#            2       1.00      1.00      1.00        15
#            3       1.00      1.00      1.00        14
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36

# %%
from sklearn.model_selection import cross_val_score,GridSearchCV
lrscore=cross_val_score(lr,x,y,cv=5)
print(lrscore)
print(lrscore.std())
print(lrscore.mean())
# Out:
# [0.75675676 0.97222222 0.83333333 1.         0.85294118]
# 0.09050663975784512
# 0.8830506977565801

# %%
from sklearn.linear_model import Ridge,Lasso

# %%
r=Ridge()
alphavalue={'alpha':[1,0.1,0.01,0.001,0]}
gd=GridSearchCV(estimator=r,param_grid=alphavalue)
gd.fit(x_train,y_train)
print(gd.best_score_)
print(gd.best_params_)
# Out:
# 0.826198385831358
# {'alpha': 1}

# %%
rd=Ridge(alpha=1)
rd.fit(x_train,y_train)
rd.score(x_train,y_train)
# Out:
# 0.864253350901649

# %%
l=Lasso()
alphavalue={'alpha':[1,0.1,0.01,0.001,0]}
grd=GridSearchCV(estimator=l,param_grid=alphavalue)
grd.fit(x_train,y_train)
print(grd.best_score_)
print(grd.best_params_)
# Out:
# 0.8265033707906927
# {'alpha': 0.001}

# %%
ls=Lasso(alpha=0.001)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
# Out:
# 0.8650217891067385

# %% [raw]
# Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()

# %%
r_value=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=r_state)
    dtc.fit(x_train,y_train)
    predd=dtc.predict(x_test)
    accuracy=accuracy_score(y_test,predd)
    if accuracy > r_value:
        r_value=accuracy
        final_r_state=r_state
print(accuracy,'at',final_r_state)
# Out:
# 0.864406779661017 at 89

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=89)
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
# Out:
# 1.0

# %%
preddt=dtc.predict(x_test)
print(accuracy_score(y_test,preddt))
print(confusion_matrix(y_test,preddt))
print(classification_report(y_test,preddt))
# Out:
# 0.9830508474576272
# [[20  0  0]
#  [ 0 22  0]
#  [ 0  1 16]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        20
#            2       0.96      1.00      0.98        22
#            3       1.00      0.94      0.97        17
#
#     accuracy                           0.98        59
#    macro avg       0.99      0.98      0.98        59
# weighted avg       0.98      0.98      0.98        59

# %%
dtcscore=cross_val_score(dtc,x,y,cv=5)
print(dtcscore.mean())
# Out:
# 0.8541961289020111

# %% [raw]
# Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
mnb=MultinomialNB()
r_sc=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=r_state)
    mnb.fit(x_train,y_train)
    predm=mnb.predict(x_test)
    accuracy=accuracy_score(y_test,predm)
    if accuracy > r_sc:
        r_sc=accuracy
        final_r=r_state
print("max r2 score corresponding to ",final_r," is ",accuracy)
# Out:
# max r2 score corresponding to  79  is  0.847457627118644

# %%
mnbscore=cross_val_score(dtc,x,y,cv=5)
print(mnbscore.mean())
# Out:
# 0.8656075403134226

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=79)
predmn=mnb.predict(x_test)
print(accuracy_score(y_test,predmn))
print(confusion_matrix(y_test,predmn))
print(classification_report(y_test,predmn))
# Out:
# 0.9661016949152542
# [[15  1  0]
#  [ 0 25  0]
#  [ 0  1 17]]
#               precision    recall  f1-score   support
#
#            1       1.00      0.94      0.97        16
#            2       0.93      1.00      0.96        25
#            3       1.00      0.94      0.97        18
#
#     accuracy                           0.97        59
#    macro avg       0.98      0.96      0.97        59
# weighted avg       0.97      0.97      0.97        59

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
r_val=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=r_state)
    knn.fit(x_train,y_train)
    pred=knn.predict(x_test)
    accuracy=accuracy_score(y_test,pred)
    if accuracy>r_val:
        r_val=accuracy
        final_r=r_state
print(accuracy,'at',final_r)
# Out:
# 0.9152542372881356 at 57

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=57)

# %%
error=[]
for i in range(1,40):
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train,y_train)
    predkn=knn.predict(x_test)
    error.append(np.mean(predkn!=y_test))

# %%
plt.plot(range(1,40),error,marker='*',markersize=10,markerfacecolor='Red',color='blue',linestyle='dashed')
plt.show()

# %%
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
# Out:
# 0.9243697478991597

# %%
predkn=knn.predict(x_test)
print(accuracy_score(y_test,predkn))
print(confusion_matrix(y_test,predkn))
print(classification_report(y_test,predkn))
# Out:
# 0.9830508474576272
# [[20  0  0]
#  [ 0 18  0]
#  [ 0  1 20]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        20
#            2       0.95      1.00      0.97        18
#            3       1.00      0.95      0.98        21
#
#     accuracy                           0.98        59
#    macro avg       0.98      0.98      0.98        59
# weighted avg       0.98      0.98      0.98        59

# %%
knnscore=cross_val_score(knn,x,y,cv=5)
print(knnscore)
print(knnscore.mean())
# Out:
# [0.83783784 0.94444444 0.86111111 1.         0.91176471]
# 0.9110316198551492

# %%
from sklearn.svm import SVC
svm=SVC()
r_val=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=r_state)
    svm.fit(x_train,y_train)
    predsv=svm.predict(x_test)
    accuracy=accuracy_score(y_test,predsv)
    if accuracy > r_val:
        r_val=accuracy
        final_r=r_state
print("max r2 score corresponding to ",final_r," is ",accuracy)
# Out:
# max r2 score corresponding to  48  is  0.9491525423728814

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=48)

from sklearn.model_selection import GridSearchCV
parameters={'kernel':['linear','rbf'],'C':[1,10,100]}
grid=GridSearchCV(svm,parameters)
grid.fit(x_train,y_train)
print(grid.best_score_)
print(grid.best_params_)
# Out:
# 0.9495798319327731
# {'C': 1, 'kernel': 'linear'}

# %%
sv=SVC(kernel='linear')
sv.fit(x_train,y_train)
pred=sv.predict(x_test)
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# 0.9830508474576272
# [[16  0  0]
#  [ 0 23  1]
#  [ 0  0 19]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        16
#            2       1.00      0.96      0.98        24
#            3       0.95      1.00      0.97        19
#
#     accuracy                           0.98        59
#    macro avg       0.98      0.99      0.98        59
# weighted avg       0.98      0.98      0.98        59

# %%
svscore=cross_val_score(svm,x,y,cv=5)
print(svscore.mean())
# Out:
# 0.956006006006006

# %%
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
rf=RandomForestClassifier()

# %%
r_val=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=r_state)
    rf.fit(x_train,y_train)
    predr=rf.predict(x_test)
    accuracy=accuracy_score(y_test,predr)
    if accuracy > r_val:
        r_val=accuracy
        final_r=r_state
print("max r2 score corresponding to ",final_r," is ",accuracy)
# Out:
# max r2 score corresponding to  47  is  0.9661016949152542

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=52)

# %%
parameters={'n_estimators':[10,100,500]}
gd=GridSearchCV(rf,parameters)
gd.fit(x_train,y_train)
print(gd.best_score_)
print(gd.best_params_)
# Out:
# 0.9747899159663865
# {'n_estimators': 100}

# %%
rf=RandomForestClassifier(n_estimators=10)
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
print(accuracy_score(y_test,predrf))
print(confusion_matrix(y_test,predrf))
print(classification_report(y_test,predrf))
# Out:
# 0.9661016949152542
# [[20  0  0]
#  [ 0 24  2]
#  [ 0  0 13]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        20
#            2       1.00      0.92      0.96        26
#            3       0.87      1.00      0.93        13
#
#     accuracy                           0.97        59
#    macro avg       0.96      0.97      0.96        59
# weighted avg       0.97      0.97      0.97        59

# %%
rfscore=cross_val_score(rf,x,y,cv=5)
print(rfscore.mean())
print(rfscore.std())
# Out:
# 0.9451686981098746
# 0.06807121675258912

# %%
gbc=GradientBoostingClassifier()
r_val=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=r_state)
    rf.fit(x_train,y_train)
    predr=rf.predict(x_test)
    accuracy=accuracy_score(y_test,predr)
    if accuracy > r_val:
        r_val=accuracy
        final_r=r_state
print("max r2 score corresponding to ",final_r," is ",accuracy)
# Out:
# max r2 score corresponding to  79  is  0.8983050847457628

# %%
parameters={"learning_rate":[0.001,0.01,0.1,1],"n_estimators":[10,100,500,1000]}
gbc=GradientBoostingClassifier()
grid=GridSearchCV(gbc, parameters)
grid.fit(x,y)
grid.best_params_
# Out:
# {'learning_rate': 0.01, 'n_estimators': 1000}

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=45)
gbc=GradientBoostingClassifier(learning_rate=0.01,n_estimators=1000)
gbc.fit(x_train,y_train)
predgb=gbc.predict(x_test)
print(accuracy_score(y_test,predgb))
print(confusion_matrix(y_test,predgb))
print(classification_report(y_test,predgb))
# Out:
# 1.0
# [[18  0  0]
#  [ 0 20  0]
#  [ 0  0 21]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        18
#            2       1.00      1.00      1.00        20
#            3       1.00      1.00      1.00        21
#
#     accuracy                           1.00        59
#    macro avg       1.00      1.00      1.00        59
# weighted avg       1.00      1.00      1.00        59

# %%
gbcscore=cross_val_score(gbc,x,y,cv=5)
print(gbcscore.mean())
print(gbcscore.std())
# Out:
# 0.9283433012844778
# 0.06247649921125487

# %% [markdown]
# Logistic Regression Algorithm has highest accuracy at random state of 48

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = 48,test_size=0.20)
lr=LogisticRegression()
lr.fit(x_train,y_train)
predlr=lr.predict(x_test)
print(accuracy_score(y_test,predlr))
print(confusion_matrix(y_test,predlr))
print(classification_report(y_test,predlr))
# Out:
# 1.0
# [[ 7  0  0]
#  [ 0 15  0]
#  [ 0  0 14]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         7
#            2       1.00      1.00      1.00        15
#            3       1.00      1.00      1.00        14
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36

# %%
lrscore=cross_val_score(lr,x,y,cv=5)
print(lrscore.mean())
print(lrscore.std())
# Out:
# 0.8830506977565801
# 0.09050663975784512

# %%
from sklearn.externals import joblib
joblib.dump(lr,'lr_winlabel.pkl')
# Out:
# ['lr_winlabel.pkl']
