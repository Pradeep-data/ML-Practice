# %%
import pandas as pd
a=pd.read_csv("C:/Users/hp/Downloads/Github/dataset1-master/winedataset.csv")
wine=pd.DataFrame(a)
wine.head()
# Out:
#    Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  diluted wines  Proline
# 0             5.64  1.04           3.92     1065
# 1             4.38  1.05           3.40     1050
# ...

# %%
wine.shape
# Out:
# (178, 14)

# %%
wine.dtypes
# Out:
# Class                     int64
# Alcohol                 float64
# Malic acid              float64
# Ash                     float64
# Alcalinity of ash       float64
# Magnesium                 int64
# Total phenols           float64
# Flavanoids              float64
# Nonflavanoid phenols    float64
# Proanthocyanins         float64
# Color intensity         float64
# Hue                     float64
# diluted wines           float64
# Proline                   int64
# dtype: object

# %%
import seaborn as sns
sns.heatmap(wine.isnull())

# %%
wine.describe()
# Out:
#             Class     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %%
sns.scatterplot(x='Magnesium',y='Alcohol',data=wine)

# %%
sns.countplot(x='Magnesium',data=wine)

# %%
wine.plot(kind='box',subplots=True,layout=(3,5))
# Out:
# Class                      AxesSubplot(0.125,0.657941;0.133621x0.222059)
# Alcohol                 AxesSubplot(0.285345,0.657941;0.133621x0.222059)
# Malic acid               AxesSubplot(0.44569,0.657941;0.133621x0.222059)
# Ash                     AxesSubplot(0.606034,0.657941;0.133621x0.222059)
# Alcalinity of ash       AxesSubplot(0.766379,0.657941;0.133621x0.222059)
# Magnesium                  AxesSubplot(0.125,0.391471;0.133621x0.222059)
# Total phenols           AxesSubplot(0.285345,0.391471;0.133621x0.222059)
# Flavanoids               AxesSubplot(0.44569,0.391471;0.133621x0.222059)
# Nonflavanoid phenols    AxesSubplot(0.606034,0.391471;0.133621x0.222059)
# Proanthocyanins         AxesSubplot(0.766379,0.391471;0.133621x0.222059)
# Color intensity               AxesSubplot(0.125,0.125;0.133621x0.222059)
# Hue                        AxesSubplot(0.285345,0.125;0.133621x0.222059)
# diluted wines               AxesSubplot(0.44569,0.125;0.133621x0.222059)
# ...

# %%
wine['Proanthocyanins'].plot.box()

# %%
import numpy as np
from scipy.stats import zscore
z=np.abs(zscore(wine))
new=wine[(z<3).all(axis=1)]

# %%
wine=new

# %%
wine.describe()
# Out:
#             Class     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  168.000000  168.000000  168.000000  168.000000         168.000000
# mean     1.934524   13.033214    2.343571    2.369226          19.361310
# std      0.790209    0.793084    1.097823    0.243202           3.118708
# min      1.000000   11.410000    0.740000    1.700000          11.200000
# 25%      1.000000   12.370000    1.610000    2.230000          17.175000
# 50%      2.000000   13.060000    1.870000    2.360000          19.250000
# 75%      3.000000   13.695000    3.105000    2.542500          21.500000
# max      3.000000   14.830000    5.650000    2.920000          28.500000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  168.000000     168.000000  168.000000            168.000000
# mean    98.779762       2.273988    2.010298              0.362679
# std     12.560477       0.627890    0.985189              0.123940
# ...

# %%
import matplotlib.pyplot as plt
wncor=wine.corr()
plt.figure(figsize=(10,6))
sns.heatmap(wncor,annot=True)

# %%
x=wine.iloc[:,1:]
y=wine.iloc[:,0]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
knn=KNeighborsClassifier()

# %%
r_val=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=r_state)
    knn.fit(x_train,y_train)
    pred=knn.predict(x_test)
    accuracy=accuracy_score(y_test,pred)
    if accuracy>r_val:
        r_val=accuracy
        final_r=r_state
print(final_r)
# Out:
# 94

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=94)

# %%
error=[]
for i in range(1,40):
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train,y_train)
    predkn=knn.predict(x_test)
    error.append(np.mean(predkn!=y_test))

# %%
plt.plot(range(1,40),error,marker='*',markersize=10,markerfacecolor='Red',color='blue',linestyle='dashed')
plt.show()

# %%
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
# Out:
# 0.8660714285714286

# %%
predkn=knn.predict(x_test)
print(accuracy_score(y_test,predkn))
print(confusion_matrix(y_test,predkn))
print(classification_report(y_test,predkn))
# Out:
# 0.7857142857142857
# [[22  0  2]
#  [ 1 13  3]
#  [ 1  5  9]]
#               precision    recall  f1-score   support
#
#            1       0.92      0.92      0.92        24
#            2       0.72      0.76      0.74        17
#            3       0.64      0.60      0.62        15
#
#     accuracy                           0.79        56
#    macro avg       0.76      0.76      0.76        56
# weighted avg       0.78      0.79      0.78        56

# %%
knnscore=cross_val_score(knn,x,y,cv=5)
print(knnscore)
print(knnscore.mean())
# Out:
# [0.71428571 0.71428571 0.67647059 0.71875    0.78125   ]
# 0.7210084033613445

# %%
from sklearn.externals import joblib

joblib.dump(knn,'knnwine.obj')
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# ['knnwine.obj']
